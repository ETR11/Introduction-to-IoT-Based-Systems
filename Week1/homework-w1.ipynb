# %% [markdown]
# # BL40A2010 Introduction to IoT-Based Systems
#
# ## Assignment 1, 18.9.2022
#
# ### Author: Eero Suomalainen

# %% [markdown]
# **(1) Analyze an electric heater as a system following Example 1.1.**

# %% [markdown]
# Peculiar operation: Uses electricity to genarate heat
#
# Conditions of production: Set of different electric machines that can convert electricity into heat
#
# Conditions of reproduction: Maintenance at regular basis and accees to the power grid
#
# External conditions: Proper personel to install it and occasionally for maintenance, money to afford it

# %% [markdown]
# **(2) Give one example for each scientific rationalities presented in Section 1.2.1 similar to Example 1.2.**

# %% [markdown]
# Classical: Observing changes in average temperatures of past years and months
#
# Non-classical: Studying combinations of information science and quantum mechanics, for example quantum computing
#
# Interventionist: Developing a quantum computer and thus affecting possibilities of computing science

# %% [markdown]
# **(3) Download the air temperature data of one year from [FMI](http://en.ilmatieteenlaitos.fi/download-observations#!/) at the city/region you currently live. Make four (arbitrary) time series plots for one year, one month, one week and one day.**
#
# *Hint:* Code like in the tutorial notebook.

# %%
pip install -r requirements.txt

# %%
import pandas as pd #https://pandas.pydata.org/
import matplotlib.pyplot as plt #https://matplotlib.org/
import matplotlib.dates as mdates #https://matplotlib.org/
import numpy as np #http://www.numpy.org/

# %%
#Air temperature of a year
Temperature = pd.read_csv("year_data.csv",dayfirst=True,sep=",", 
                          header=0,decimal=b".",index_col=0,
                          parse_dates= [[0, 1, 2, 3]],usecols=[0,1,2,3,5])
Temperature.info()

plt.figure(figsize=(16,6)) 
plt.plot(Temperature,color='blue', marker='x',linestyle=':') 
plt.title("Air temperature in sep 17 2021 - sep 17 2022, at Kouvola Utti airport station") 
plt.ylabel("Temperature in [°C]") 
plt.grid(True) 
plt.show()
#######################

# %%
#Air temperature of a month
Temperature = pd.read_csv("month_data.csv",dayfirst=True,sep=",", 
                          header=0,decimal=b".",index_col=0,
                          parse_dates= [[0, 1, 2, 3]],usecols=[0,1,2,3,5])
Temperature.info()

plt.figure(figsize=(16,6)) 
plt.plot(Temperature,color='blue', marker='x',linestyle=':') 
plt.title("Air temperature in aug 17 2022 - sep 17 2022, at Kouvola Utti airport station") 
plt.ylabel("Temperature in [°C]") 
plt.grid(True) 
plt.show()
#######################

# %%
#Air temperature of a week
Temperature = pd.read_csv("week_data.csv",dayfirst=True,sep=",", 
                          header=0,decimal=b".",index_col=0,
                          parse_dates= [[0, 1, 2, 3]],usecols=[0,1,2,3,5])
Temperature.info()

plt.figure(figsize=(16,6)) 
plt.plot(Temperature,color='blue', marker='x',linestyle=':') 
plt.title("Air temperature in sep 10 2022 - sep 17 2022, at Kouvola Utti airport station") 
plt.ylabel("Temperature in [°C]") 
plt.grid(True) 
plt.show()
#######################

# %%
#Air temperature of a day
Temperature = pd.read_csv("day_data.csv",dayfirst=True,sep=",", 
                          header=0,decimal=b".",index_col=0,
                          parse_dates= [[0, 1, 2, 3]],usecols=[0,1,2,3,5])
Temperature.info()

plt.figure(figsize=(16,6)) 
plt.plot(Temperature,color='blue', marker='x',linestyle=':') 
plt.title("Air temperature in sep 17 2022, at Kouvola Utti airport station") 
plt.ylabel("Temperature in [°C]") 
plt.grid(True) 
plt.show()
#######################

# %% [markdown]
# **(4) Consider a house with an electric heater. How the electricity consumption of the heater would be affected by the air temperature? Is there a way to change this?**

# %% [markdown]
# Higher air temperature can reduce use of the heater which in return lowers its electricity consumption and vice versa. Lowering room temperature when it's cold outside reduces power input of the heater and lowers the electricity consumption.
